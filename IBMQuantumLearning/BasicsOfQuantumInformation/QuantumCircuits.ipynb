# %% [markdown]
# Imports

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.primitives import Sampler
from qiskit.visualization import plot_histogram

# %% [markdown]
# Define a ciruit with one Qubit and apply unitary operations

# %%
circuit = QuantumCircuit(1)
circuit.h(0)
circuit.s(0)
circuit.h(0)
circuit.t(0)
circuit.draw("mpl")

# %% [markdown]
# Define a 1 Qubit circuit using a Quantum Register then apply unitary operations to the register

# %%
X = QuantumRegister(1, "X")
circuit = QuantumCircuit(X)
circuit.h(X)
circuit.s(X)
circuit.h(X)
circuit.t(X)
circuit.draw("mpl")

# %% [markdown]
# With a circuit containing two qubits applying a hadamard gate to the first qubit and and identity gate to the second followed by a controlled-NOT gate with the first qubit as a control and the second as the target each of the bell basis states can be obtained.

# %%
X = QuantumRegister(1, "x")
Y = QuantumRegister(1, "y")
A = ClassicalRegister(1, "a")
B = ClassicalRegister(1, "b")

circuit = QuantumCircuit(Y, X, B, A)
circuit.h(Y)
circuit.cx(Y, X)
circuit.measure(Y, B)
circuit.measure(X, A)

display(circuit.draw("mpl"))

# %%
sampler = Sampler()
results = sampler.run(circuit).result()
statistics = results.quasi_dists[0].binary_probabilities()
display(plot_histogram(statistics))
